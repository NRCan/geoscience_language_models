# %%
import os
import xml.etree.ElementTree as ET
from os import path, makedirs
import csv
import pandas as pd

# %%
root_dir = "/nrcan_p2"
data_dir = path.join(root_dir,"data")
geoscan_files_dir = path.join(data_dir,"01_raw","20201006","geoscan")
raw_dir = path.join(geoscan_files_dir, "raw")
zip_dir = path.join(raw_dir, "zip")
pdf_dir = path.join(raw_dir, "pdf")

# %%
tree = ET.parse(path.join(geoscan_files_dir, 'EAIDown.xml'))

# %%
root = tree.getroot()

# %%
print(root.text)
print(root.tag)
print(root.attrib)
# Out:
# {https://geoscan.nrcan.gc.ca/schema/osdp_feed/1.0/}dataroot
# {'{http://www.w3.org/2001/XMLSchema-instance}schemaLocation': 'https://geoscan.nrcan.gc.ca/schema/osdp_feed/1.0/ https://geoscan.nrcan.gc.ca/schema/osdp_feed/1.0/geoscan.xsd'}

# %%
# Looking at first element of root 
for child in list(root)[0]:
    print(child.tag, child.attrib, child.text)
    print('\n')
#     pprint(child.tag)#, child.attrib, child.text)
#     pprint(child.attrib)
#     pprint(child.text)
# Out:
# {http://purl.org/dc/elements/1.1/}contributor {} GEOSCAN
#
#
# {http://purl.org/dc/elements/1.1/}title {'{http://www.w3.org/XML/1998/namespace}lang': 'en'} Rock-Eval/TOC data for ten southwest Alberta wells (townships 16 to 30, ranges 2 to 10W5)
#
#
# {http://purl.org/dc/elements/1.1/}creator {} Watson, C
#
#
# {http://purl.org/dc/elements/1.1/}creator {} Jayachandran, P T
#
#
# {http://purl.org/dc/elements/1.1/}creator {} Spanswick, E
#
#
# {http://purl.org/dc/elements/1.1/}creator {} Donovan, E F
#
#
# {http://purl.org/dc/elements/1.1/}creator {} Danskin, D W
#
#
# {http://purl.org/dc/elements/1.1/}subject {'{http://www.w3.org/XML/1998/namespace}lang': 'en'} wells
#
#
# {http://purl.org/dc/elements/1.1/}subject {'{http://www.w3.org/XML/1998/namespace}lang': 'en'} lithology
#
#
# {http://purl.org/dc/elements/1.1/}subject {'{http://www.w3.org/XML/1998/namespace}lang': 'en'} thermal maturation
#
#
# {http://purl.org/dc/elements/1.1/}subject {'{http://www.w3.org/XML/1998/namespace}lang': 'en'} hydrocarbon migration
#
#
# {http://purl.org/dc/elements/1.1/}subject {'{http://www.w3.org/XML/1998/namespace}lang': 'en'} hydrocarbon generation
#
#
# {http://purl.org/dc/elements/1.1/}subject {'{http://www.w3.org/XML/1998/namespace}lang': 'en'} hydrocarbon potential
#
#
# {http://purl.org/dc/elements/1.1/}subject {'{http://www.w3.org/XML/1998/namespace}lang': 'en'} hydrocarbons
#
#
# {http://purl.org/dc/elements/1.1/}subject {'{http://www.w3.org/XML/1998/namespace}lang': 'en'} Elbow River 11-15-20-7W5 well
#
#
# {http://purl.org/dc/elements/1.1/}subject {'{http://www.w3.org/XML/1998/namespace}lang': 'en'} Futurity Gap 16-17-24-9W5 well
#
#
# {http://purl.org/dc/elements/1.1/}subject {'{http://www.w3.org/XML/1998/namespace}lang': 'en'} Harmattan East 7-9-33-3W5 well
#
#
# {http://purl.org/dc/elements/1.1/}subject {'{http://www.w3.org/XML/1998/namespace}lang': 'en'} West Hunter Valley 11-16-29-9W5 well
#
#
# {http://purl.org/dc/elements/1.1/}subject {'{http://www.w3.org/XML/1998/namespace}lang': 'en'} Jumpingpound Creek 7-4-25-5W5 well
#
#
# {http://purl.org/dc/elements/1.1/}subject {'{http://www.w3.org/XML/1998/namespace}lang': 'en'} Panther River 9-19-30-10W5 well
#
#
# {http://purl.org/dc/elements/1.1/}subject {'{http://www.w3.org/XML/1998/namespace}lang': 'en'} Sheep 5-29-18-3W5 well
#
#
# {http://purl.org/dc/elements/1.1/}subject {'{http://www.w3.org/XML/1998/namespace}lang': 'en'} Stimson Creek 9-36-16-4W5 well
#
#
# {http://purl.org/dc/elements/1.1/}subject {'{http://www.w3.org/XML/1998/namespace}lang': 'en'} Sullivan 6-15-18-5W5 well
#
#
# {http://purl.org/dc/elements/1.1/}subject {'{http://www.w3.org/XML/1998/namespace}lang': 'en'} Turner Valley 16-14-18-2W5 well
#
#
# {http://purl.org/dc/elements/1.1/}subject {'{http://www.w3.org/XML/1998/namespace}lang': 'en'} rock-eval analyses
#
#
# {http://purl.org/dc/elements/1.1/}subject {'{http://www.w3.org/XML/1998/namespace}lang': 'en'} total organic carbon
#
#
# {http://purl.org/dc/elements/1.1/}subject {'{http://www.w3.org/XML/1998/namespace}lang': 'en'} fossil fuels
#
#
# {http://purl.org/dc/elements/1.1/}subject {'{http://www.w3.org/XML/1998/namespace}lang': 'fr'} puits
#
#
# {http://purl.org/dc/elements/1.1/}subject {'{http://www.w3.org/XML/1998/namespace}lang': 'fr'} lithologie
#
#
# {http://purl.org/dc/elements/1.1/}subject {'{http://www.w3.org/XML/1998/namespace}lang': 'fr'} maturation thermique
#
#
# {http://purl.org/dc/elements/1.1/}subject {'{http://www.w3.org/XML/1998/namespace}lang': 'fr'} migration des hydrocarbures
#
#
# {http://purl.org/dc/elements/1.1/}subject {'{http://www.w3.org/XML/1998/namespace}lang': 'fr'} production d'hydrocarbure
#
#
# {http://purl.org/dc/elements/1.1/}subject {'{http://www.w3.org/XML/1998/namespace}lang': 'fr'} capacité de production d'hydrocarbures
#
#
# {http://purl.org/dc/elements/1.1/}subject {'{http://www.w3.org/XML/1998/namespace}lang': 'fr'} hydrocarbures
#
#
# {http://purl.org/dc/elements/1.1/}subject {'{http://www.w3.org/XML/1998/namespace}lang': 'fr'} Puit Elbow River 11-15-20-7w5
#
#
# {http://purl.org/dc/elements/1.1/}subject {'{http://www.w3.org/XML/1998/namespace}lang': 'fr'} Puit Futurity Gap 16-17-24-9w5
#
#
# {http://purl.org/dc/elements/1.1/}subject {'{http://www.w3.org/XML/1998/namespace}lang': 'fr'} Puit Harmattan East 7-9-33-3w5
#
#
# {http://purl.org/dc/elements/1.1/}subject {'{http://www.w3.org/XML/1998/namespace}lang': 'fr'} Puit West Hunter Valley 11-16-29-9w5
#
#
# {http://purl.org/dc/elements/1.1/}subject {'{http://www.w3.org/XML/1998/namespace}lang': 'fr'} Puit Jumpingpound Creek 7-4-25-5w5
#
#
# {http://purl.org/dc/elements/1.1/}subject {'{http://www.w3.org/XML/1998/namespace}lang': 'fr'} Puit Panther River 9-19-30-10w5
#
#
# {http://purl.org/dc/elements/1.1/}subject {'{http://www.w3.org/XML/1998/namespace}lang': 'fr'} Puit Sheep 5-29-18-3w5
#
#
# {http://purl.org/dc/elements/1.1/}subject {'{http://www.w3.org/XML/1998/namespace}lang': 'fr'} Puit Stimson Creek 9-36-16-4w5
#
#
# {http://purl.org/dc/elements/1.1/}subject {'{http://www.w3.org/XML/1998/namespace}lang': 'fr'} Puit Sullivan 6-15-18-5w5
#
#
# {http://purl.org/dc/elements/1.1/}subject {'{http://www.w3.org/XML/1998/namespace}lang': 'fr'} Puit Turner Valley 16-14-18-2w5
#
#
# {http://purl.org/dc/elements/1.1/}subject {'{http://www.w3.org/XML/1998/namespace}lang': 'fr'} None
#
#
# {http://purl.org/dc/elements/1.1/}subject {'{http://www.w3.org/XML/1998/namespace}lang': 'fr'} None
#
#
# {http://purl.org/dc/elements/1.1/}subject {'{http://www.w3.org/XML/1998/namespace}lang': 'fr'} combustibles fossiles
#
#
# {http://purl.org/dc/elements/1.1/}source {'{http://www.w3.org/XML/1998/namespace}lang': 'en'} Geological Survey of Canada, Open File 2916, 114 pages; 10.4095/407
#
#
# {http://purl.org/dc/elements/1.1/}source {'{http://www.w3.org/XML/1998/namespace}lang': 'fr'} Commission géologique du Canada, Dossier public 2916, 114 pages; 10.4095/407
#
#
# {http://purl.org/dc/elements/1.1/}description {'{http://www.w3.org/XML/1998/namespace}lang': 'en'} None
#
#
# {http://purl.org/dc/elements/1.1/}description {'{http://www.w3.org/XML/1998/namespace}lang': 'fr'} None
#
#
# {http://purl.org/dc/elements/1.1/}date {} 1994
#
#
# {http://purl.org/dc/elements/1.1/}type {'{http://www.w3.org/XML/1998/namespace}lang': 'en'} Report
#
#
# {http://purl.org/dc/elements/1.1/}format {'{http://www.w3.org/XML/1998/namespace}lang': 'en'} on-line
#
#
# {http://purl.org/dc/elements/1.1/}format {'{http://www.w3.org/XML/1998/namespace}lang': 'fr'} en ligne
#
#
# {http://purl.org/dc/elements/1.1/}format {} pdf
#
#
# {http://purl.org/dc/elements/1.1/}format {} Open Access
#
#
# {http://purl.org/dc/elements/1.1/}identifier {} geoscanid:407
#
#
# {http://purl.org/dc/elements/1.1/}identifier {'{http://www.w3.org/XML/1998/namespace}lang': 'en'} https://geoscan.nrcan.gc.ca/starweb/geoscan/servlet.starweb?path=geoscan/fulle.web&search1=R=407
#
#
# {http://purl.org/dc/elements/1.1/}identifier {'{http://www.w3.org/XML/1998/namespace}lang': 'en'} https://ftp.geogratis.gc.ca/pub/nrcan_rncan/publications/ess_sst/0/407/of_2916.zip
#
#
# {http://purl.org/dc/elements/1.1/}identifier {'{http://www.w3.org/XML/1998/namespace}lang': 'fr'} https://geoscan.nrcan.gc.ca/starweb/geoscan/servlet.starweb?path=geoscan/fullf.web&search1=R=407
#
#
# {http://purl.org/dc/elements/1.1/}identifier {} info:doi/10.4095/407
#
#
# {http://purl.org/dc/elements/1.1/}language {} eng
#
#
# {http://purl.org/dc/elements/1.1/}coverage {'{http://www.w3.org/XML/1998/namespace}lang': 'en'} Alberta Foothills
#
#
# {http://purl.org/dc/elements/1.1/}coverage {} POLYGON((49.0000 -112.0000, 49.0000 -114.0000, 52.0000 -117.0000, 52.0000 -112.0000, 49.0000 -112.0000))
#
#
# {http://purl.org/dc/elements/1.1/}coverage {'{http://www.w3.org/XML/1998/namespace}lang': 'en'} Alberta
#
#
# {http://purl.org/dc/elements/1.1/}coverage {'{http://www.w3.org/XML/1998/namespace}lang': 'fr'} Alberta
#
#
# {http://purl.org/dc/elements/1.1/}rights {'{http://www.w3.org/XML/1998/namespace}lang': 'en'} https://open.canada.ca/en/open-government-licence-canada
#
#
# {http://purl.org/dc/elements/1.1/}rights {'{http://www.w3.org/XML/1998/namespace}lang': 'fr'} https://ouvert.canada.ca/fr/licence-du-gouvernement-ouvert-canada

# %%
for child in root[0]:
    print(child.tag)
# Out:
# {http://purl.org/dc/elements/1.1/}contributor
# {http://purl.org/dc/elements/1.1/}title
# {http://purl.org/dc/elements/1.1/}creator
# {http://purl.org/dc/elements/1.1/}creator
# {http://purl.org/dc/elements/1.1/}creator
# {http://purl.org/dc/elements/1.1/}creator
# {http://purl.org/dc/elements/1.1/}creator
# {http://purl.org/dc/elements/1.1/}subject
# {http://purl.org/dc/elements/1.1/}subject
# {http://purl.org/dc/elements/1.1/}subject
# {http://purl.org/dc/elements/1.1/}subject
# {http://purl.org/dc/elements/1.1/}subject
# {http://purl.org/dc/elements/1.1/}subject
# {http://purl.org/dc/elements/1.1/}subject
# {http://purl.org/dc/elements/1.1/}subject
# {http://purl.org/dc/elements/1.1/}subject
# {http://purl.org/dc/elements/1.1/}subject
# {http://purl.org/dc/elements/1.1/}subject
# {http://purl.org/dc/elements/1.1/}subject
# {http://purl.org/dc/elements/1.1/}subject
# {http://purl.org/dc/elements/1.1/}subject
# {http://purl.org/dc/elements/1.1/}subject
# {http://purl.org/dc/elements/1.1/}subject
# {http://purl.org/dc/elements/1.1/}subject
# {http://purl.org/dc/elements/1.1/}subject
# {http://purl.org/dc/elements/1.1/}subject
# {http://purl.org/dc/elements/1.1/}subject
# {http://purl.org/dc/elements/1.1/}subject
# {http://purl.org/dc/elements/1.1/}subject
# {http://purl.org/dc/elements/1.1/}subject
# {http://purl.org/dc/elements/1.1/}subject
# {http://purl.org/dc/elements/1.1/}subject
# {http://purl.org/dc/elements/1.1/}subject
# {http://purl.org/dc/elements/1.1/}subject
# {http://purl.org/dc/elements/1.1/}subject
# {http://purl.org/dc/elements/1.1/}subject
# {http://purl.org/dc/elements/1.1/}subject
# {http://purl.org/dc/elements/1.1/}subject
# {http://purl.org/dc/elements/1.1/}subject
# {http://purl.org/dc/elements/1.1/}subject
# {http://purl.org/dc/elements/1.1/}subject
# {http://purl.org/dc/elements/1.1/}subject
# {http://purl.org/dc/elements/1.1/}subject
# {http://purl.org/dc/elements/1.1/}subject
# {http://purl.org/dc/elements/1.1/}subject
# {http://purl.org/dc/elements/1.1/}subject
# {http://purl.org/dc/elements/1.1/}subject
# {http://purl.org/dc/elements/1.1/}source
# {http://purl.org/dc/elements/1.1/}source
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}description
# {http://purl.org/dc/elements/1.1/}date
# {http://purl.org/dc/elements/1.1/}type
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}format
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}identifier
# {http://purl.org/dc/elements/1.1/}language
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}coverage
# {http://purl.org/dc/elements/1.1/}rights
# {http://purl.org/dc/elements/1.1/}rights

# %%
def parse_keywords(xml_article):
    
    # TODO: split keywords into individual words to find in the title 
    
    """
    Returning a set of words defined as Subjects of the article that match the language for the 
    Language attribute of the article. 
    """
    # TODO: few articles have lang not english or french
    lang = xml_article.findall("{http://purl.org/dc/elements/1.1/}language")[0].text
    
    identifiers = xml_article.findall("{http://purl.org/dc/elements/1.1/}identifier")
    for identifier in identifiers:
        text = identifier.text
        if "geoscanid:" in text:
            geo_id = text.split(":")[1]
    
    keywords = set()
            
    for subject in xml_article.findall("{http://purl.org/dc/elements/1.1/}subject"):

        # English is eng in language field but en in subject field
        # French is fre in language field but fr in subject field
        if list(subject.attrib.values())[0] in lang:
            # if no subjects matching language
            try:
                keywords.add(subject.text.lower())
            except:
                pass

    return geo_id, keywords

# %%
def create_keyword_dict(root):

    """
    Creates dictionary containing an article's geoscan ID and keywords.
    """
    
    keyword_dict = {}
    
    for article in root:
        geo_id, keywords = parse_keywords(article)
        keyword_dict[geo_id] = keywords
        
    return keyword_dict

# %%
def search_title(xml_article, keywords=None):
    
    """
    Search article title if it contains keywords.
    """
    
    title = xml_article.findall("{http://purl.org/dc/elements/1.1/}title")[0].text.lower()
    print(title)
    return title

# %%
for c, i in enumerate(root[2:3]):
    geo_id, keywords = parse_keywords(i)
    print(geo_id, keywords)
# Out:
# 4681 {'paleontology', 'fossil distribution, geographic', 'invertebrata', 'fossil lists'}

# %%
# a few of the articles that are not designated as english or french
# 7579
# 8284
# 11026

# %%
keyword_dict = create_keyword_dict(root)

# %%
# number of articles metadata is provided for 
len(keyword_dict)
# Out:
# 12316

# %%
# total number of files extracted as pdf or zip in this directory (there are more in total)
print('zip: ', len(os.listdir(zip_dir)))
print('pdf: ', len(os.listdir(pdf_dir)))
len(os.listdir(zip_dir)) + len(os.listdir(pdf_dir))
# Out:
# zip:  4873
# pdf:  7183
# 12056

# %%
geoscan_files_dir
# Out:
# '/nrcan_p2/data/01_raw/20201006/geoscan'

# %%
mypath = path.join(geoscan_files_dir, 'GEOSCAN-extract-20200211144755.xml_df.parquet')
# path.join(geoscan_files_dir, 'GEOSCAN')

# %%
df = pd.read_parquet(mypath)

# %%
df
# Out:
#       {http://purl.org/dc/elements/1.1/}contributor  \
# 0                                         [GEOSCAN]
# 1                                         [GEOSCAN]
# 2                                         [GEOSCAN]
# 3                                         [GEOSCAN]
# 4                                         [GEOSCAN]
# ...                                             ...
# 92658                                     [GEOSCAN]
# 92659                                     [GEOSCAN]
# 92660                                     [GEOSCAN]
# 92661                                     [GEOSCAN]
# 92662                                     [GEOSCAN]
#
#               {http://purl.org/dc/elements/1.1/}title_en  \
# 0      [Voggite, a new hydrated Na-Zr hydroxide-phosp...
# 1      [The inversion of time-domain airborne electro...
# 2      [Lithosphere folds in the Eurekan orogen, Arct...
# 3                                                   None
# 4           [Archaean Geology; Dating Old Gold Deposits]
# ...                                                  ...
# 92658  [Clumped isotope temperature calibration for c...
# 92659  [An Overview on Isotopic Divergences - Causes ...
# 92660           [Catalogue of Mines Branch Publications]
# 92661  [Catalogue of Mines Branch Publications, with ...
# 92662  [Development of shale gas prediction models fo...
#
#                {http://purl.org/dc/elements/1.1/}creator  \
# 0      [Roberts, A C, Sabina, A P, Ercit, T S, Grice,...
# 1                          [Keating, P B, Crossley, D J]
# 2      [Stephenson, R A, Ricketts, B D, Cloetingh, S ...
# 3                          [Geological Survey of Canada]
# 4                            [Thomas, G, Whalley, B J P]
# ...                                                  ...
# 92658  [Jautzy, J J, Martine, M M, Dhillon, R S, Bern...
# 92659                             [Savard, M M, Daux, V]
# 92660                       [Canada Department of Mines]
# 92661                       [Canada Department of Mines]
# 92662                 [Nguyen-Le, V, Shin, H, Little, E]
#
#             {http://purl.org/dc/elements/1.1/}subject_en  \
# 0      [phosphates, carbonates, minerals, optical pro...
# 1      [geophysical surveys, geophysical interpretati...
# 2      [tectonophysics, orogenies, structural feature...
# 3      [structural analyses, structural interpretatio...
# 4      [gold, mineral deposits, radiometric dates, ur...
# ...                                                  ...
# 92658                                             [None]
# 92659                                             [None]
# 92660                                             [None]
# 92661                                             [None]
# 92662  [petroleum resources, hydrocarbons, gas, model...
#
#             {http://purl.org/dc/elements/1.1/}subject_fr  \
# 0      [minéraux de phosphates, carbonates, minéraux,...
# 1      [levés géophysiques, interprétations géophysiq...
# 2      [tectonophysique, orogénies, caractéristiques ...
# 3      [analyses structurales, interpretations struct...
# 4      [or, gisements minéraux, datations radiométriq...
# ...                                                  ...
# 92658                                               None
# 92659                                               None
# 92660                                               None
# 92661                                               None
# 92662  [ressources pétrolières, hydrocarbures, gaz, m...
#
#              {http://purl.org/dc/elements/1.1/}source_en  \
# 0      [Canadian Mineralogist vol. 28, no. 1,  p. 155...
# 1      [Geophysics vol. 55, no. 6,  p. 705-711; 10.11...
# 2      [Geology vol. 18, no. 7,  p. 603-606; 10.1130/...
# 3      [Geological Survey of Canada; Géologie de l'Or...
# 4               [Nature vol. 346, no. 6287,  p. 792-793]
# ...                                                  ...
# 92658                 [Geochemical Perspectives Letters]
# 92659                              [Climate of the Past]
# 92660  [Canada Mines Branch, Publication 337, , 28 pa...
# 92661  [Canada Mines Branch, Publication 337, , 35 pa...
# 92662  [Energies vol. 13, issue 2, , 424 p. 1-17; 10....
#
#              {http://purl.org/dc/elements/1.1/}source_fr  \
# 0      [Canadian Mineralogist vol. 28, no. 1,  p. 155...
# 1      [Geophysics vol. 55, no. 6,  p. 705-711; 10.11...
# 2      [Geology vol. 18, no. 7,  p. 603-606; 10.1130/...
# 3      [Commission géologique du Canada; Géologie de ...
# 4               [Nature vol. 346, no. 6287,  p. 792-793]
# ...                                                  ...
# 92658                 [Geochemical Perspectives Letters]
# 92659                              [Climate of the Past]
# 92660  [Canada Direction des mines, Publication 337, ...
# 92661  [Canada Direction des mines, Publication 337, ...
# 92662  [Energies vol. 13, issue 2, , 424 p. 1-17; 10....
#
#         {http://purl.org/dc/elements/1.1/}description_en  \
# 0                                                 [None]
# 1      [Airborne electromagnetic (EM) methods were de...
# 2      [Cornwall and Princess Margaret arches are maj...
# 3                                                 [None]
# 4                                                 [None]
# ...                                                  ...
# 92658                                [Clumped isotope (]
# 92659  [Climatic reconstructions based on tree-ring i...
# 92660                                             [None]
# 92661                                             [None]
# 92662  [This study examined the relationship between ...
#
#       {http://purl.org/dc/elements/1.1/}description_fr  \
# 0                                               [None]
# 1                                               [None]
# 2                                               [None]
# 3                                               [None]
# 4                                               [None]
# ...                                                ...
# 92658                                           [None]
# 92659                                           [None]
# 92660                                           [None]
# 92661                                           [None]
# 92662                                           [None]
#
#       {http://purl.org/dc/elements/1.1/}date  ...  \
# 0                                     [1990]  ...
# 1                                     [1990]  ...
# 2                                     [1990]  ...
# 3                                     [1991]  ...
# 4                                     [1990]  ...
# ...                                      ...  ...
# 92658                                   None  ...
# 92659                                   None  ...
# 92660                                 [1917]  ...
# 92661                                 [1921]  ...
# 92662                                 [2020]  ...
#
#       {http://purl.org/dc/elements/1.1/}publisher_fr  \
# 0                                               None
# 1                                             [None]
# 2                                             [None]
# 3                                               None
# 4                                               None
# ...                                              ...
# 92658                                         [None]
# 92659                                         [None]
# 92660                    [Canada Division des mines]
# 92661                    [Canada Division des mines]
# 92662                                         [None]
#
#       {http://purl.org/dc/elements/1.1/}format_en  \
# 0                                            None
# 1                                       [on-line]
# 2                                       [on-line]
# 3                                       [on-line]
# 4                                            None
# ...                                           ...
# 92658                                   [on-line]
# 92659                                   [on-line]
# 92660                                        None
# 92661                                        None
# 92662                                   [on-line]
#
#       {http://purl.org/dc/elements/1.1/}format_fr  \
# 0                                            None
# 1                                      [en ligne]
# 2                                      [en ligne]
# 3                                      [en ligne]
# 4                                            None
# ...                                           ...
# 92658                                  [en ligne]
# 92659                                  [en ligne]
# 92660                                        None
# 92661                                        None
# 92662                                  [en ligne]
#
#       {http://purl.org/dc/elements/1.1/}identifier_info  \
# 0                                                  None
# 1                               [doi/10.1190/1.1442882]
# 2                                                  None
# 3                                     [doi/10.4095/270]
# 4                                                  None
# ...                                                 ...
# 92658                                              None
# 92659                                              None
# 92660                              [doi/10.4095/321799]
# 92661                                              None
# 92662                          [doi/10.3390/en13020424]
#
#               {http://purl.org/dc/elements/1.1/}coverage  \
# 0                                                   None
# 1                                                   None
# 2      [POLYGON((76.0000 -64.0000, 76.0000 -104.0000,...
# 3      [POLYGON((74.0000 -62.0000, 74.0000 -124.0000,...
# 4                                                   None
# ...                                                  ...
# 92658                                               None
# 92659                                               None
# 92660                                               None
# 92661                                               None
# 92662  [POLYGON((31.7500 -96.3333, 31.7500 -98.5000, ...
#
#             {http://purl.org/dc/elements/1.1/}identifier  \
# 0                                                   None
# 1                                                   None
# 2      [info:doi/10.1130/0091-7613(1990)018<0603:LFIT...
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 92658                                               None
# 92659                                               None
# 92660                                               None
# 92661                                               None
# 92662                                               None
#
#               {http://purl.org/dc/elements/1.1/}title_fr  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3      [Introduction [Chapitre 12: Phases de déformat...
# 4                                                   None
# ...                                                  ...
# 92658                                               None
# 92659                                               None
# 92660                                               None
# 92661                                               None
# 92662                                               None
#
#              {http://purl.org/dc/elements/1.1/}rights_en  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3      [https://open.canada.ca/en/open-government-lic...
# 4                                                   None
# ...                                                  ...
# 92658                                               None
# 92659                                               None
# 92660                                               None
# 92661                                               None
# 92662                                               None
#
#              {http://purl.org/dc/elements/1.1/}rights_fr  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3      [https://ouvert.canada.ca/fr/licence-du-gouver...
# 4                                                   None
# ...                                                  ...
# 92658                                               None
# 92659                                               None
# 92660                                               None
# 92661                                               None
# 92662                                               None
#
#       {http://purl.org/dc/elements/1.1/}title
# 0                                        None
# 1                                        None
# 2                                        None
# 3                                        None
# 4                                        None
# ...                                       ...
# 92658                                    None
# 92659                                    None
# 92660                                    None
# 92661                                    None
# 92662                                    None
#
# [92663 rows x 29 columns]

# %%
df['{http://purl.org/dc/elements/1.1/}identifier_geoscanid']
# Out:
# 0           [134]
# 1           [146]
# 2           [253]
# 3           [270]
# 4           [373]
#            ...
# 92658    [321797]
# 92659    [321798]
# 92660    [321799]
# 92661    [321800]
# 92662    [321801]
# Name: {http://purl.org/dc/elements/1.1/}identifier_geoscanid, Length: 92663, dtype: object
