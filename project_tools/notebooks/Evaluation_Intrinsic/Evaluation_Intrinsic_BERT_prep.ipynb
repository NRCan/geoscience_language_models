# %% [markdown]
# # Prepare static BERT embeddings for intrinsic evaluation
# Copyright (C) 2021 ServiceNow, Inc.
#
# BERT embeds tokens/words dynamically with context. However, we would still like to find a reasonable way to obtain static embeddings for words and use the intrinsic evaluation tasks to compare it with the GloVe embeddings. The approach we adopt is that we feed in [CLS] + word + [SEP] as the input, then perform average pooling on the last layer hidden states that correspond to the word. We use the averaged vector of dim (768, ) as the representation of the word.
#
# Note that since our BERT models are trained on sentences, using single words as input may not generate as powerful embeddings as it could with full sentences.

# %%
import pathlib
REPO_DIR = pathlib.Path(__name__).parent.absolute().parent
print(REPO_DIR)
# Out:
# /nrcan_p2/workspace/tianyi/nrcan_p2

# %%
import sys
sys.path.append(str(REPO_DIR))

# %%
# output directory of the embedding map
OUTPUT_FOLDER = '/nrcan_p2/data/07_model_output/bert_geology_evaluation'
EMBEDDING_FOLDER = '/nrcan_p2/data/06_models/bert_nrcan_embeddings'

# %%
# %load_ext autoreload
# %autoreload 2

# %%
def load_words(words):
    words = [word.lower().split() for l in words for word in l]
    words = set([w for s in words for w in s])
    return words

# %%
from nrcan_p2.evaluation.load_test_data import (
    load_analogy_data, load_similarity_data, load_nearest_neighbour_data, load_word_cluster_data)

# %%
analogy_tests = load_analogy_data(REPO_DIR / 'nrcan_p2/evaluation/2020_ElementAI_Test_CJML_02_Dec-16-2020 - Analogy.csv')
display(analogy_tests)
# Out:
# Analogy data contains: 66 analogies in 9 themes
#        Task                          Theme           a               x  \
# 0   Analogy                        Geology     Abitibi        Superior
# 1   Analogy                        Geology        Core          Mantle
# 2   Analogy                        Geology        Core           Inner
# 3   Analogy                        Geology  Deposition   Sedimentation
# 4   Analogy                        Geology   Diverging           Ridge
# ..      ...                            ...         ...             ...
# 61  Analogy  Geology_Petrology_Sedimentary   Turbidite          Marine
# 62  Analogy             Geology_Structural       Gouge  Unconsolidated
# 63  Analogy             Geology_Structural       Norma       Extension
# 64  Analogy             Geology_Structural      Plunge       Lineation
# 65  Analogy             Geology_Structural   Transform           Fault
#
#                   b             y
# 0          Stikinia   Cordilleran
# 1        Phenocryst           Rim
# 2             Crust         Outer
# 3   Crystallization     Magmatism
# 4        Converging      Mountain
# ..              ...           ...
# 61        Sandstone       Fluvial
# 62      Cataclasite  Consolidated
# 63          Reverse   Compression
# 64           Strike        Planar
# 65        Anticline          Fold
#
# [66 rows x 6 columns]

# %%
analogy_words = analogy_tests[["a", "x", "b", "y"]].values.tolist()
analogy_words = load_words(analogy_words)
analogy_words
# Out:
# {'abitibi',
#  'actinolite',
#  'albite',
#  'alkaline',
#  'amphibole',
#  'amphibolite',
#  'andesite',
#  'angular',
#  'anisotropic',
#  'anorthite',
#  'anticline',
#  'aphanitic',
#  'archean',
#  'arenite',
#  'arkose',
#  'asthenosphere',
#  'basalt',
#  'basanite',
#  'basin',
#  'batholith',
#  'biotite',
#  'black',
#  'blueschist',
#  'breccia',
#  'calcite',
#  'carbonate',
#  'cataclasite',
#  'chalcopyrite',
#  'chemical',
#  'chlorite',
#  'clastic',
#  'clay',
#  'coarse',
#  'cold',
#  'compression',
#  'concordant',
#  'conductive',
#  'conglomerate',
#  'consolidated',
#  'convecting',
#  'converging',
#  'cooling',
#  'copper',
#  'cordilleran',
#  'core',
#  'crust',
#  'crystallization',
#  'cyclosilicate',
#  'deep',
#  'deposition',
#  'detritus',
#  'diamond',
#  'diopside',
#  'discordant',
#  'diverging',
#  'drumlin',
#  'dyke',
#  'dykes',
#  'earth',
#  'eon',
#  'epidote',
#  'erosion',
#  'eruption',
#  'extension',
#  'extrusive',
#  'fast',
#  'fault',
#  'feldspar',
#  'felsic',
#  'fine',
#  'fluid',
#  'fluvial',
#  'fold',
#  'foliated',
#  'fossil',
#  'geochemistry',
#  'glacier',
#  'gneiss',
#  'gold',
#  'gouge',
#  'granite',
#  'granulite',
#  'graphite',
#  'green',
#  'greenschist',
#  'greenstone',
#  'grenville',
#  'heating',
#  'hydrology',
#  'hydrothermal',
#  'hypabyssal',
#  'igneous',
#  'inner',
#  'intermediate',
#  'intrusive',
#  'isotropic',
#  'jurassic',
#  'kyanite',
#  'limestone',
#  'lineation',
#  'lithification',
#  'lithium',
#  'lithosphere',
#  'mafic',
#  'magma',
#  'magmatic',
#  'magmatism',
#  'magnetic',
#  'magnetite',
#  'mantle',
#  'marble',
#  'marine',
#  'massive',
#  'melting',
#  'metamorphic',
#  'microscope',
#  'moho',
#  'molybdneum',
#  'mountain',
#  'mudstone',
#  'muscovite',
#  'nickel',
#  'norma',
#  'olivine',
#  'optical',
#  'outer',
#  'oxide',
#  'paleontology',
#  'pegmatite',
#  'pentlandite',
#  'peridotite',
#  'period',
#  'phaneritic',
#  'phenocryst',
#  'phyllosilicate',
#  'planar',
#  'planet',
#  'plunge',
#  'plutonic',
#  'porphyry',
#  'proterozoic',
#  'province',
#  'pyroxene',
#  'quartz',
#  'quartzite',
#  'resistive',
#  'reverse',
#  'rhyolite',
#  'ridge',
#  'rigid',
#  'rim',
#  'river',
#  'rock',
#  'rounded',
#  'sand',
#  'sandstone',
#  'scarp',
#  'sedimentary',
#  'sedimentation',
#  'sericite',
#  'serpentine',
#  'shale',
#  'shallow',
#  'silicate',
#  'sill',
#  'sillimanite',
#  'slate',
#  'slow',
#  'sorosilicate',
#  'source',
#  'spectrometer',
#  'star',
#  'stikinia',
#  'strike',
#  'subalkaline',
#  'subsidence',
#  'sulphide',
#  'sun',
#  'superior',
#  'tectosilicate',
#  'terrane',
#  'tourmaline',
#  'transform',
#  'trap',
#  'tsunami',
#  'turbidite',
#  'unconsolidated',
#  'uplift',
#  'vein',
#  'veins',
#  'volcanic',
#  'volcano',
#  'water',
#  'wave'}

# %%
relatedness_tests = load_similarity_data(REPO_DIR / 'nrcan_p2/evaluation/2020_ElementAI_Test_CJML_03_Feb-23-2020-Relatedness.csv')
display(relatedness_tests)
# Out:
# Relatedness data contains: 249 relatedness examples in 14 themes
#             Task                 Theme Include synonym Spelling variation   y  \
# 0    Relatedness  Earth System Science              No                NaN NaN
# 1    Relatedness  Earth System Science              No                NaN NaN
# 2    Relatedness  Earth System Science              No                NaN NaN
# 3    Relatedness  Earth System Science              No                NaN NaN
# 4    Relatedness  Earth System Science              No                NaN NaN
# ..           ...                   ...             ...                ...  ..
# 244  Relatedness               Methods              No                NaN NaN
# 245  Relatedness               Methods              No                NaN NaN
# 246  Relatedness               Methods              No                NaN NaN
# 247  Relatedness               Methods              No                NaN NaN
# 248  Relatedness               Methods              No                NaN NaN
#
#                 a x (Words with decreasing similarity ->) Unnamed: 7  \
# 0             Age                             Uncertainty        NaN
# 1             Air                            Stratosphere        NaN
# 2          Alkali                               Potassium        NaN
# 3          Alpine                                Mountain        NaN
# 4            Atom                                 Nucleus        NaN
# ..            ...                                     ...        ...
# 244      Magnetic                          Susceptibility        NaN
# 245        Plasma                                   Laser        NaN
# 246     Reference                                Standard        NaN
# 247       Seismic                                    Wave        NaN
# 248  Spectroscopy                            Spectrometry        NaN
#
#     Unnamed: 8 Unnamed: 9  ... Unnamed: 14 Unnamed: 15 Unnamed: 16  \
# 0          NaN        NaN  ...         NaN         NaN         NaN
# 1          NaN        NaN  ...         NaN         NaN         NaN
# 2          NaN        NaN  ...         NaN         NaN         NaN
# 3          NaN        NaN  ...         NaN         NaN         NaN
# 4          NaN        NaN  ...         NaN         NaN         NaN
# ..         ...        ...  ...         ...         ...         ...
# 244        NaN        NaN  ...         NaN         NaN         NaN
# 245        NaN        NaN  ...         NaN         NaN         NaN
# 246        NaN        NaN  ...         NaN         NaN         NaN
# 247        NaN        NaN  ...         NaN         NaN         NaN
# 248        NaN        NaN  ...         NaN         NaN         NaN
#
#     Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21 Unnamed: 22  \
# 0           NaN         NaN         NaN         NaN         NaN         NaN
# 1           NaN         NaN         NaN         NaN         NaN         NaN
# 2           NaN         NaN         NaN         NaN         NaN         NaN
# 3           NaN         NaN         NaN         NaN         NaN         NaN
# 4           NaN         NaN         NaN         NaN         NaN         NaN
# ..          ...         ...         ...         ...         ...         ...
# 244         NaN         NaN         NaN         NaN         NaN         NaN
# 245         NaN         NaN         NaN         NaN         NaN         NaN
# 246         NaN         NaN         NaN         NaN         NaN         NaN
# 247         NaN         NaN         NaN         NaN         NaN         NaN
# 248         NaN         NaN         NaN         NaN         NaN         NaN
#
#                                 l
# 0              [Age, Uncertainty]
# 1             [Air, Stratosphere]
# 2             [Alkali, Potassium]
# 3              [Alpine, Mountain]
# 4                 [Atom, Nucleus]
# ..                            ...
# 244    [Magnetic, Susceptibility]
# 245               [Plasma, Laser]
# 246         [Reference, Standard]
# 247               [Seismic, Wave]
# 248  [Spectroscopy, Spectrometry]
#
# [249 rows x 24 columns]

# %%
relatedness_words = relatedness_tests[["x (Words with decreasing similarity ->)", "a"]].values.tolist()
relatedness_words = load_words(relatedness_words)
relatedness_words
# Out:
# {'abitibi',
#  'abrasion',
#  'acicular',
#  'age',
#  'air',
#  'albite',
#  'alkali',
#  'almandite',
#  'alpine',
#  'alteration',
#  'aluminim',
#  'amphibolite',
#  'analysis',
#  'angular',
#  'anorthite',
#  'anorthosite',
#  'anthropogenic',
#  'arc',
#  'archean',
#  'arcuate',
#  'arenite',
#  'argillic',
#  'arkose',
#  'ash',
#  'athabasca',
#  'atom',
#  'auerole',
#  'augite',
#  'barometer',
#  'barrier',
#  'basalt',
#  'base',
#  'bedding',
#  'biology',
#  'biotite',
#  'bladed',
#  'blueschist',
#  'boulder',
#  'boundary',
#  'breccia',
#  'burial',
#  'buttress',
#  'calcsilicate',
#  'carbonate',
#  'cataclasite',
#  'categorical',
#  'cementation',
#  'chalk',
#  'change',
#  'charnokite',
#  'chert',
#  'chlorine',
#  'chloritic',
#  'chrome',
#  'clay',
#  'cleavage',
#  'climate',
#  'coarse',
#  'coast',
#  'cobalt',
#  'cobble',
#  'compaction',
#  'complex',
#  'component',
#  'conductive',
#  'conduit',
#  'conglomerate',
#  'contact',
#  'contemporary',
#  'continuous',
#  'copper',
#  'coquine',
#  'cordillera',
#  'crystal',
#  'cumulate',
#  'curved',
#  'dacite',
#  'death',
#  'deformed',
#  'density',
#  'dependency',
#  'deposition',
#  'diabase',
#  'diamictite',
#  'diamond',
#  'diapir',
#  'diffraction',
#  'dike',
#  'diopside',
#  'diorite',
#  'discharge',
#  'discrete',
#  'disposal',
#  'dolostone',
#  'driver',
#  'ductile',
#  'dyke',
#  'dynamic',
#  'earthquake',
#  'eclogite',
#  'ecology',
#  'edge',
#  'electron',
#  'eletrical',
#  'eletron',
#  'elongation',
#  'enderbite',
#  'energy',
#  'enstatite',
#  'enveloped',
#  'environment',
#  'eoarchean',
#  'equant',
#  'equilibrium',
#  'erosion',
#  'estimate',
#  'euhedral',
#  'evaporation',
#  'evolution',
#  'exfoliation',
#  'extinction',
#  'extrapolation',
#  'fault',
#  'fauna',
#  'fayalite',
#  'feedback',
#  'ferrosilite',
#  'ferruginous',
#  'flat',
#  'flin',
#  'flon',
#  'flood',
#  'flow',
#  'flux',
#  'folded',
#  'foliation',
#  'forecast',
#  'forsterite',
#  'fossil',
#  'fracture',
#  'future',
#  'gabbro',
#  'geochemistry',
#  'geography',
#  'glacial',
#  'gneiss',
#  'gold',
#  'gouge',
#  'government',
#  'graben',
#  'granite',
#  'granitoid',
#  'granodiorite',
#  'granulite',
#  'gravity',
#  'greenschist',
#  'greisen',
#  'groundwater',
#  'group',
#  'hadean',
#  'halide',
#  'hard',
#  'harzburgite',
#  'hematite',
#  'hornfels',
#  'horst',
#  'human',
#  'humid',
#  'hurricane',
#  'hydrogen',
#  'hydrolysis',
#  'hydrothermal',
#  'hyperspectral',
#  'hypersthene',
#  'image',
#  'inclusion',
#  'indurated',
#  'integration',
#  'intrusion',
#  'iron',
#  'isostasy',
#  'isotope',
#  'isotropic',
#  'joint',
#  'komatiite',
#  'laccolith',
#  'landform',
#  'landslide',
#  'laser',
#  'laterite',
#  'lava',
#  'layering',
#  'lead',
#  'lherzolite',
#  'life',
#  'limestone',
#  'lineation',
#  'linkage',
#  'lithic',
#  'lithosphere',
#  'loose',
#  'lopolith',
#  'mafic',
#  'magmatism',
#  'magnetic',
#  'magnetite',
#  'magnitude',
#  'manitoba',
#  'marble',
#  'marine',
#  'mass',
#  'measurement',
#  'megacryst',
#  'melt',
#  'mica',
#  'mineral',
#  'mississippian',
#  'model',
#  'modern',
#  'moisture',
#  'molybdenum',
#  'monzogranite',
#  'monzonite',
#  'moon',
#  'mount',
#  'mountain',
#  'mud',
#  'muscovite',
#  'mylonite',
#  'neutron',
#  'nickel',
#  'norite',
#  'nucleus',
#  'numerical',
#  'oblate',
#  'observation',
#  'ocean',
#  'oil',
#  'oligoclase',
#  'olivine',
#  'ontario',
#  'orographic',
#  'oscillatory',
#  'pahoehoe',
#  'paleoarchean',
#  'paleontology',
#  'palladium',
#  'pathway',
#  'pedalogy',
#  'pelitic',
#  'pennsylvanian',
#  'peridotite',
#  'petroleum',
#  'phenocryst',
#  'phonolite',
#  'phyllite',
#  'pigeonite',
#  'planar',
#  'plasma',
#  'plastic',
#  'plate',
#  'platinum',
#  'policy',
#  'porosity',
#  'porphyroblast',
#  'porphyry',
#  'potassic',
#  'potassium',
#  'precipitation',
#  'prediction',
#  'pressure',
#  'probable',
#  'prolate',
#  'proton',
#  'proven',
#  'psammite',
#  'pyrite',
#  'pyroxene',
#  'pyroxenite',
#  'pyrrhotite',
#  'quartz',
#  'quarzite',
#  'quebec',
#  'radiolarian',
#  'raglan',
#  'reference',
#  'reflection',
#  'research',
#  'reserve',
#  'reservoir',
#  'resorbed',
#  'resource',
#  'rhyolite',
#  'ribbon',
#  'ridge',
#  'rimmed',
#  'river',
#  'rock',
#  'rod',
#  'root',
#  'rounded',
#  'runoff',
#  'salt',
#  'sandstone',
#  'sanidinite',
#  'saskatchewan',
#  'satellite',
#  'scalar',
#  'scatter',
#  'sedimentology',
#  'seismic',
#  'sericite',
#  'serpentine',
#  'shale',
#  'shear',
#  'sheet',
#  'shelf',
#  'silica',
#  'sill',
#  'silver',
#  'sink',
#  'slate',
#  'slave',
#  'slickenline',
#  'snowmelt',
#  'soil',
#  'solid',
#  'source',
#  'space',
#  'spectrometry',
#  'spectroscopy',
#  'spessartine',
#  'stable',
#  'standard',
#  'state',
#  'strata',
#  'stratigraphy',
#  'stratosphere',
#  'stretching',
#  'subaerial',
#  'subangular',
#  'subaqueous',
#  'subduction',
#  'subhedral',
#  'sudbury',
#  'sulfide',
#  'sulphide',
#  'sun',
#  'supergroup',
#  'surface',
#  'susceptibility',
#  'sustainable',
#  'syenite',
#  'syenogranite',
#  'synthesis',
#  'system',
#  'tectonics',
#  'telluride',
#  'tellurium',
#  'tephrite',
#  'thin',
#  'threshold',
#  'tide',
#  'tonalite',
#  'trachyte',
#  'trachytic',
#  'trajectory',
#  'transition',
#  'transpiration',
#  'trap',
#  'trilobite',
#  'troctolite',
#  'tsunami',
#  'tuff',
#  'ultramafic',
#  'uncertainty',
#  'unconsolidated',
#  'uplift',
#  'uranium',
#  'vein',
#  'vent',
#  'vesicular',
#  'volcanic',
#  'volcanism',
#  'volcano',
#  'wacke',
#  'waste',
#  'water',
#  'wave',
#  'weather',
#  'weathering',
#  'wind',
#  'xenolith',
#  'zeolite',
#  'zinc',
#  'zoning'}

# %%
nn_tests = load_nearest_neighbour_data(REPO_DIR / 'nrcan_p2/evaluation/2020_ElementAI_Test_CJML_03_Jan-4-2020-NearestNeighbours.csv')
display(nn_tests)
# Out:
# Nearest neighbor data contains: 5 words
#    ID         Word
# 0   1        Earth
# 1   2  Exploration
# 2   3  Environment
# 3   4      Climate
# 4   5       Hazard

# %%
nn_words = nn_tests[["Word"]].values.tolist()
nn_words = load_words(nn_words)
nn_words
# Out:
# {'climate', 'earth', 'environment', 'exploration', 'hazard'}

# %%
cluster_tests = load_word_cluster_data(REPO_DIR / 'nrcan_p2/evaluation/2020_ElementAI_Test_CJML_03_Jan-4-2020-WordClusters.csv')
display(cluster_tests)
# Out:
# Word cluster data contains: 16 clusters and 900 total words
#                   Cluster          Word
# 0        Alteration types      argillic
# 1        Alteration types       albitic
# 2        Alteration types      alunitic
# 3        Alteration types  calcsilicate
# 4        Alteration types     carbonate
# ..                    ...           ...
# 895  Exploration activity      sampling
# 896  Exploration activity    subsurface
# 897  Exploration activity       surface
# 898  Exploration activity    systematic
# 899  Exploration activity          test
#
# [900 rows x 2 columns]

# %%
cluster_words = cluster_tests[["Word"]].values.tolist()
cluster_words = load_words(cluster_words)
cluster_words
# Out:
# {'abyssal',
#  'accretion',
#  'accumulation',
#  'acid',
#  'acidic',
#  'aeolian',
#  'agate',
#  'aggregate',
#  'albitic',
#  'alkali',
#  'alluvial',
#  'alteration',
#  'alumina',
#  'aluminium',
#  'aluminosilicate',
#  'alunite',
#  'alunitic',
#  'amazonite',
#  'amber',
#  'amethyst',
#  'amphibolite',
#  'amygdule',
#  'andalusite',
#  'andesite',
#  'angle',
#  'angular',
#  'anhedral',
#  'anhydrite',
#  'anisotropic',
#  'anorthosite',
#  'anorthositic',
#  'anoxic',
#  'anthophyllite',
#  'anthracite',
#  'anthropogenic',
#  'antimony',
#  'apatite',
#  'aphanite',
#  'aplite',
#  'aquamarine',
#  'arc',
#  'arch',
#  'arcuate',
#  'arenite',
#  'argillic',
#  'arid',
#  'arkosic',
#  'arsenic',
#  'asbestos',
#  'ash',
#  'asphalt',
#  'assessment',
#  'augen',
#  'auger',
#  'autoclast',
#  'axiolite',
#  'backreef',
#  'banding',
#  'barium',
#  'barrier',
#  'baryte',
#  'basalt',
#  'basanite',
#  'basic',
#  'basin',
#  'bathyal',
#  'bauxite',
#  'beach',
#  'bedding',
#  'beneficiation',
#  'bentonite',
#  'beryl',
#  'beryllium',
#  'bioclast',
#  'bioclastic',
#  'biogenic',
#  'biological',
#  'bismuth',
#  'bituminous',
#  'blanket',
#  'bleb',
#  'blob',
#  'block',
#  'bog',
#  'boninite',
#  'borate',
#  'boron',
#  'boudin',
#  'boulder',
#  'boundstone',
#  'breakup',
#  'breccia',
#  'bromine',
#  'cadmium',
#  'calcareous',
#  'calcite',
#  'calcsilicate',
#  'carbonaceous',
#  'carbonate',
#  'carbonatite',
#  'carnallite',
#  'carnelian',
#  'cassiterite',
#  'cataclasite',
#  'cataclastic',
#  'cave',
#  'cavity',
#  'cerium',
#  'cesium',
#  'chalcedony',
#  'chalk',
#  'channel',
#  'chemical',
#  'chert',
#  'chlorite',
#  'chloritic',
#  'chrome',
#  'chromite',
#  'chromium',
#  'chrysoberyl',
#  'chrysoprase',
#  'chrysotile',
#  'circular',
#  'citrine',
#  'clast',
#  'clastic',
#  'clay',
#  'claystone',
#  'cleavage',
#  'coal',
#  'coast',
#  'coated',
#  'cobalt',
#  'cobble',
#  'cognate',
#  'collapse',
#  'collision',
#  'collisional',
#  'column',
#  'comb',
#  'composite',
#  'compound',
#  'concretionary',
#  'cone',
#  'conglomerate',
#  'conical',
#  'contact',
#  'continental',
#  'continuous',
#  'copper',
#  'coprolite',
#  'cordierite',
#  'core',
#  'corundum',
#  'creep',
#  'crenulation',
#  'crocidolite',
#  'crude',
#  'crustal',
#  'cryolite',
#  'cryptomicrobial',
#  'crystal',
#  'crystalline',
#  'crystallisation',
#  'crystallite',
#  'cumulate',
#  'cupola',
#  'cylinder',
#  'dacite',
#  'deformation',
#  'delta',
#  'deltaic',
#  'depletion',
#  'deposition',
#  'detachment',
#  'detailed',
#  'deuteric',
#  'dextral',
#  'diagenetic',
#  'diamictite',
#  'diamicton',
#  'diamond',
#  'diapir',
#  'diatomite',
#  'differentiation',
#  'diffuse',
#  'diffusion',
#  'dike',
#  'dimensional',
#  'dioptase',
#  'diorite',
#  'dioritic',
#  'dioritoid',
#  'disc',
#  'discharge',
#  'discoid',
#  'discrete',
#  'discus',
#  'disjunct',
#  'disjunctive',
#  'dislocation',
#  'dissolution',
#  'distributary',
#  'disturbance',
#  'doleritic',
#  'dolomite',
#  'dolomitic',
#  'domainal',
#  'dome',
#  'drainage',
#  'drilling',
#  'ductile',
#  'ductolith',
#  'dumortierite',
#  'dunefield',
#  'duricrust',
#  'dust',
#  'dysprosium',
#  'eclogite',
#  'effusive',
#  'ellipsoid',
#  'elongate',
#  'emerald',
#  'emission',
#  'englacial',
#  'epiclast',
#  'epicontinental',
#  'epidote',
#  'epsomite',
#  'equant',
#  'erbium',
#  'erosion',
#  'eruption',
#  'estimate',
#  'estuarine',
#  'estuary',
#  'ethmolith',
#  'euclase',
#  'euhedral',
#  'europium',
#  'eutaxitic',
#  'evaluation',
#  'evaporite',
#  'excavation',
#  'exotic',
#  'extinction',
#  'extraction',
#  'extrusive',
#  'fabric',
#  'failure',
#  'fall',
#  'fan',
#  'fault',
#  'faulting',
#  'feasibility',
#  'fecal',
#  'feldspar',
#  'feldspathic',
#  'fenestra',
#  'ferromagnesian',
#  'ferruginous',
#  'fiamme',
#  'fibre',
#  'fissile',
#  'flaser',
#  'flat',
#  'floodplain',
#  'flow',
#  'fluorine',
#  'fluorite',
#  'foid',
#  'foidite',
#  'foiditoid',
#  'foidolite',
#  'folding',
#  'foliated',
#  'foliation',
#  'forearc',
#  'foreland',
#  'forereef',
#  'formed',
#  'fossil',
#  'fracturing',
#  'fragment',
#  'fragmental',
#  'framestone',
#  'gabbro',
#  'gabbroid',
#  'gadolinium',
#  'gallium',
#  'garnet',
#  'gas',
#  'gaseous',
#  'gemstone',
#  'generic',
#  'geochemistry',
#  'geology',
#  'geophysics',
#  'germanium',
#  'gibber',
#  'glacial',
#  'glass',
#  'glassy',
#  'glauconite',
#  'glaucophane',
#  'glaukophanschiefer',
#  'glomerocryst',
#  'gneiss',
#  'gneissic',
#  'gold',
#  'gouge',
#  'graben',
#  'grading',
#  'grainstone',
#  'granite',
#  'granitoid',
#  'granodiorite',
#  'granofels',
#  'granular',
#  'granulite',
#  'graphite',
#  'gravel',
#  'greenschist',
#  'greenstone',
#  'greisen',
#  'grit',
#  'gypsum',
#  'habitat',
#  'hadal',
#  'hafnium',
#  'halloysite',
#  'haloclasty',
#  'health',
#  'heat',
#  'heliodor',
#  'hematite',
#  'hematitic',
#  'hemispheroid',
#  'high',
#  'highland',
#  'hillslope',
#  'hinterland',
#  'holmium',
#  'holoblast',
#  'horizontal',
#  'hornblendite',
#  'hornfels',
#  'hybrid',
#  'hydration',
#  'hydroclast',
#  'hydrolysis',
#  'hydrothermal',
#  'hypabyssal',
#  'igneous',
#  'ilmenite',
#  'imbricated',
#  'impact',
#  'impersistent',
#  'impure',
#  'inclusion',
#  'indium',
#  'instability',
#  'interdistributary',
#  'interior',
#  'intermediate',
#  'interpretation',
#  'intersection',
#  'intertidal',
#  'intraclast',
#  'intraplate',
#  'intrusion',
#  'intrusive',
#  'iodine',
#  'iridium',
#  'iron',
#  'irregular',
#  'isotropic',
#  'jade',
#  'jarosite',
#  'joints',
#  'kalsilitic',
#  'kaolin',
#  'kaolinitic',
#  'kohle',
#  'komatiitic',
#  'kornerupine',
#  'kyanite',
#  'laccolith',
#  'lacustrine',
#  'lagoon',
#  'lamination',
#  'landslide',
#  'lanthanum',
#  'lapillistone',
#  'laterite',
#  'latite',
#  'latitic',
#  'layer',
#  'layering',
#  'lazulite',
#  'lead',
#  'lens',
#  'lenticular',
#  'leucoxene',
#  'lignite',
#  'lime',
#  'limestone',
#  'lineation',
#  'liquid',
#  'lithic',
#  'lithium',
#  'lithophysae',
#  'longitudinal',
#  'lopolith',
#  'low',
#  'lower',
#  'lutetium',
#  'mafic',
#  'magnesia',
#  'magnesian',
#  'magnesite',
#  'magnesium',
#  'magnetite',
#  'malachite',
#  'manganese',
#  'mantle',
#  'marble',
#  'margin',
#  'marine',
#  'meander',
#  'medium',
#  'melting',
#  'mercury',
#  'metal',
#  'metalloid',
#  'metaluminous',
#  'metamorphic',
#  'metamorphism',
#  'metaplutonic',
#  'metasedimentary',
#  'metasomatic',
#  'metavolcanic',
#  'miarolitic',
#  'mica',
#  'micaceous',
#  'microfracturing',
#  'microlite',
#  'migmatite',
#  'mineral',
#  'mineralogical',
#  'molybdenite',
#  'molybdenum',
#  'monazite',
#  'monomictic',
#  'monzodiorite',
#  'monzogabbro',
#  'monzogranite',
#  'monzonite',
#  'moonstone',
#  'morganite',
#  'moss',
#  'mound',
#  'mud',
#  'mudstone',
#  'mylonite',
#  'mylonitic',
#  'neodymium',
#  'neritic',
#  'nickel',
#  'niobium',
#  'nitrate',
#  'nodule',
#  'noise',
#  'normal',
#  'obduction',
#  'oblique',
#  'obsidian',
#  'oceanic',
#  'ochre',
#  'odour',
#  'oil',
#  'olivine',
#  'oncoid',
#  'onyx',
#  'ooid',
#  'ooze',
#  'opal',
#  'orb',
#  'organic',
#  'orthogneiss',
#  'osmium',
#  'oxidation',
#  'oxide',
#  'packstone',
#  'paleoblast',
#  'palladium',
#  'palygorskite',
#  'pancake',
#  'paragneiss',
#  'parallel',
#  'paramorph',
#  'particle',
#  'particulate',
#  'passive',
#  'peat',
#  'pebble',
#  'pediment',
#  'pegmatite',
#  'pelitic',
#  'peloid',
#  'pencil',
#  'peralkaline',
#  'peraluminous',
#  'percussion',
#  'peridotite',
#  'perlite',
#  'phacolith',
#  'phaneritic',
#  'phenakite',
#  'phonolite',
#  'phonolitic',
#  'phonolitoid',
#  'phosphate',
#  'phosphatic',
#  'phosphorite',
#  'phosphorous',
#  'phyllite',
#  'phyllitic',
#  'phyllonite',
#  'physical',
#  'piedmont',
#  'piedra',
#  'pillow',
#  'pilot',
#  'pipe',
#  'pisoid',
#  'plain',
#  'planar',
#  'platform',
#  'platinum',
#  'playa',
#  'plutonic',
#  'pod',
#  'polar',
#  'polygonal',
#  'porphyry',
#  'potash',
#  'potassic',
#  'potassium',
#  'pozzolan',
#  'praseodymium',
#  'precipitation',
#  'prehnite',
#  'primary',
#  'prism',
#  'prodelta',
#  'profile',
#  'proglacial',
#  'promethium',
#  'propylitic',
#  'protomylonite',
#  'pseudomorph',
#  'pumice',
#  'pure',
#  'pyrite',
#  'pyritic',
#  'pyroclast',
#  'pyroclastic',
#  'pyrophyllite',
#  'pyroxene',
#  'pyroxenite',
#  'quartz',
#  'quartzite',
#  'quartzose',
#  'radiation',
#  'radioactive',
#  'radium',
#  'reconnaissance',
#  'reef',
#  'regional',
#  'residual',
#  'resorbed',
#  'resource',
#  'reversal',
#  'reverse',
#  'rhenium',
#  'rhodium',
#  'rhodonite',
#  'rhyolite',
#  'rhyolitoid',
#  'rhythmic',
#  'ribbon',
#  'rift',
#  'rifting',
#  'ring',
#  'riprap',
#  'rise',
#  'river',
#  'rock',
#  'rocky',
#  'rod',
#  'rodding',
#  'rough',
#  'rounded',
#  'rubidium',
#  'ruby',
#  'runoff',
#  'ruthenium',
#  'rutile',
#  'sabkha',
#  'salt',
#  'samarium',
#  'sampling',
#  'sand',
#  'sandstone',
#  'sanidinite',
#  'saponite',
#  'sapphire',
#  'sapphirine',
#  'sapropel',
#  'saussuritised',
#  'scaly',
#  'scandium',
#  'scapolite',
#  'schist',
#  'schistosity',
#  'schlieren',
#  'scissor',
#  'seamount',
#  'sediment',
#  'sedimentary',
#  'sedimentation',
#  'segment',
#  'selenium',
#  'sepiolite',
#  'sericite',
#  'sericitic',
#  'serpentine',
#  'serpentinisation',
#  'serpentinite',
#  'shale',
#  'shape',
#  'shard',
#  'shattering',
#  'shearing',
#  'sheet',
#  'shelf',
#  'shell',
#  'shoreline',
#  'sigmoid',
#  'sigmoidal',
#  'silica',
#  'silicate',
#  'siliceous',
#  'silicic',
#  'silicification',
#  'silicon',
#  'sill',
#  'sillimanite',
#  'silt',
#  'siltstone',
#  'silver',
#  'sinhalite',
#  'sinistral',
#  'skarn',
#  'slate',
#  'slaty',
#  'slickenline',
#  'slope',
#  'soda',
#  'sodalite',
#  'solid',
#  'solution',
#  'space',
#  'spaced',
#  'speciation',
#  'spectrolite',
#  'sphenolith',
#  'spheroid',
#  'spherule',
#  'spilite',
#  'spinel',
#  'spodumene',
#  'spongolite',
#  'spreading',
#  'square',
#  'staurolite',
#  'strandplain',
#  'stretching',
#  'strike',
#  'stromatic',
#  'stromatolitic',
#  'strontianite',
#  'strontium',
#  'subaerial',
#  'subangular',
#  'subaqueous',
#  'subduction',
#  'subglacial',
#  'subgreenschist',
#  'subhedral',
#  'submarine',
#  'subrounded',
#  'subsidence',
#  'subsurface',
#  'sulfate',
#  'sulfide',
#  'sulphur',
#  'supraglacial',
#  'supratidal',
#  'surface',
#  'swamp',
#  'syenite',
#  'syenitic',
#  'syenitoid',
#  'syenogranite',
#  'sylvite',
#  'syngenetic',
#  'systematic',
#  'tablet',
#  'tabular',
#  'talc',
#  'tantalum',
#  'tanzanite',
#  'tar',
#  'tear',
#  'tectonic',
#  'tellurium',
#  'temperate',
#  'tephra',
#  'tephrite',
#  'tephritic',
#  'tephritoid',
#  'terbium',
#  'terminus',
#  'terrane',
#  'terrestrial',
#  'test',
#  'thallium',
#  'thenardite',
#  'tholeiitic',
#  'thorium',
#  'thrust',
#  'thulium',
#  'tidal',
#  'tin',
#  'titanium',
#  'tonalite',
#  'topaz',
#  'tourmaline',
#  'trachyte',
#  'trachytic',
#  'trachytoid',
#  'transform',
#  'transitional',
#  'transport',
#  'transposed',
#  'travertine',
#  'trench',
#  'tropical',
#  'trough',
#  'tsavorite',
#  'tuff',
#  'tuffit',
#  'tuffite',
#  'tungsten',
#  'turquoise',
#  'twinning',
#  'ultrabasic',
#  'ultramafic',
#  'ultramylonite',
#  'unconsolidated',
#  'undulating',
#  'upper',
#  'uralitisation',
#  'uranium',
#  'vague',
#  'vanadium',
#  'variole',
#  'variscite',
#  'varve',
#  'vein',
#  'ventrifact',
#  'vermiculite',
#  'vesicle',
#  'vesuvianite',
#  'vibration',
#  'volcanic',
#  'volcaniclastic',
#  'vug',
#  'wacke',
#  'wander',
#  'wasting',
#  'water',
#  'weathering',
#  'wedge',
#  'wetland',
#  'wind',
#  'wollastonite',
#  'wrench',
#  'xenocryst',
#  'ytterbium',
#  'yttrium',
#  'zeolite',
#  'zeolitic',
#  'zinc',
#  'zircon',
#  'zirconia',
#  'zirconium'}

# %%
all_words = set(list(analogy_words) + list(relatedness_words) + list(nn_words) + list(cluster_words))
len(all_words)
# Out:
# 1115

# %%
# check if all entries are single words
for word in all_words:
    if len(word.split()) > 1:
        print(word)

# %%
from functions import bert
import pandas as pd

# %%
# read the model map in
models_df = pd.read_csv(f"{OUTPUT_FOLDER}/bert_geology_evaluation/BERT_MODEL_MAP.csv")
models_df.head()
# Out:
#   dataset pipeline   tokenizer  \
# 0       a       v1  pretrained
# 1      ab       v1  pretrained
# 2     abd       v1  pretrained
# 3       a       80  pretrained
# 4      ab       80  pretrained
#
#                                                 path  dim
# 0  /nrcan_p2/mlflow_data/42/83d34150748641b89a44b...  786
# 1  /nrcan_p2/mlflow_data/40/902f7aba032a402a92705...  786
# 2  /nrcan_p2/mlflow_data/49/dbc77f67097b4937adcb9...  786
# 3  /nrcan_p2/mlflow_data/51/9212f6a912664e3d9c949...  786
# 4  /nrcan_p2/mlflow_data/52/16b01e423ebe4f08a0111...  786

# %%
def create_text_file(vocabulary, filename, model, tokenizer):

    """
    Creates a text file containing a word and its BERT embedding on each line.
    To be loaded into a KeyedVectors object to store keys/vectors.
    """

    assert filename.split('.')[-1] == 'txt', "Filename must be a .txt file"

    f = open(filename, 'w')
    # Write first line for word2vec format
    f.write(str(len(vocabulary)) + ' ' + str(bert_model.config.hidden_size))
    f.write('\n')
    # Write words and embeddings
    for i, word in enumerate(vocabulary):
#         print(i)
        f.write(word + ' ')
        # Create BERT embedding
        vector = bert.bert_embedding(word, tokenizer, model, to_numpy=True)
        for v in vector:
            f.write(str(v) + ' ')
        f.write('\n')

    f.close()

# %%
for index, row in models_df.iterrows():
    print(index, f"Creating embeddding file for {row.path}")
    bert_model, bert_tokenizer, bert_config = bert.load_bert(model_name_or_path=row.path)
    model_file = f"{EMBEDDING_FOLDER}/bert.{row.dataset}.{row.pipeline}.{row.tokenizer}.{row.dim}.txt"
    create_text_file(all_words, model_file, bert_model, bert_tokenizer)
    models_df["embedding_path"].iloc[index] = model_file
# Out:
# 0 Creating embeddding file for /nrcan_p2/mlflow_data/42/83d34150748641b89a44b74a1beaf799/model/best_model
# 1 Creating embeddding file for /nrcan_p2/mlflow_data/40/902f7aba032a402a927059958a38e079/model/best_model
# 2 Creating embeddding file for /nrcan_p2/mlflow_data/49/dbc77f67097b4937adcb914e8895ba2c/model/best_model
# 3 Creating embeddding file for /nrcan_p2/mlflow_data/51/9212f6a912664e3d9c949cc35db9d60b/model/best_model
# 4 Creating embeddding file for /nrcan_p2/mlflow_data/52/16b01e423ebe4f08a0111809eef7830e/model/best_model
# 5 Creating embeddding file for /nrcan_p2/mlflow_data/53/f6d9eefc176241e0b63654c63e97f901/model/best_model
# 6 Creating embeddding file for /nrcan_p2/mlflow_data/55/97683cfa22c145faa3e0d1cc64d2d22f/model/best_model
# 7 Creating embeddding file for /nrcan_p2/mlflow_data/54/9583ad61ff32407bb799716cfe197902/model/best_model
# 8 Creating embeddding file for /nrcan_p2/mlflow_data/58/48c9caa04c6f490d84645e64f8abf99b/model/best_model
# 9 Creating embeddding file for /nrcan_p2/mlflow_data/59/e99fa92098fe4d99b990523245d7c88c/model/best_model
# 10 Creating embeddding file for /nrcan_p2/mlflow_data/60/47dd5bbf53fd41a19af10114b040f73f/model/best_model
# 11 Creating embeddding file for /nrcan_p2/mlflow_data/111/aa511d0956044554a6003b03281caa81/model/best_model
# 12 Creating embeddding file for /nrcan_p2/mlflow_data/122/80c6425f81cf42589bde23cd0a76b25e/model/best_model
# 13 Creating embeddding file for /nrcan_p2/mlflow_data/117/cf48bd9e386c4016b91f2d4a6de105fb/model/best_model
# 14 Creating embeddding file for /nrcan_p2/mlflow_data/115/c9ed23ca6b85429aacaa4d4430383066/model/best_model
# 15 Creating embeddding file for /nrcan_p2/mlflow_data/116/4bb189b9348042d09d6739d55acd70d8/model/best_model
# 16 Creating embeddding file for /nrcan_p2/mlflow_data/123/2a668c76d62e408f98c2e20e39ffe837/model/best_model
# 17 Creating embeddding file for /nrcan_p2/mlflow_data/121/ef9952d289794ba78b6b597c1871069c/model/best_model
# 18 Creating embeddding file for /nrcan_p2/mlflow_data/118/b09e1d46195e457d8113c13828522fdb/model/best_model
# 19 Creating embeddding file for /nrcan_p2/mlflow_data/112/23646f5808e648fca301bdab453c9af0/model/best_model
# 20 Creating embeddding file for /nrcan_p2/mlflow_data/114/a31bd6a676e34f0ab168a09f077ec93f/model/best_model
# 21 Creating embeddding file for /nrcan_p2/mlflow_data/124/6a053efc28174894bb39f2a6a7e10ddf/model/best_model
# 22 Creating embeddding file for /nrcan_p2/mlflow_data/96/9b369d7fb505460589f89f58a7d16bde/model/best_model
# 23 Creating embeddding file for /nrcan_p2/mlflow_data/109/259c962823fd4794bca074bc0ad0ea48/model/best_model
# 24 Creating embeddding file for /nrcan_p2/mlflow_data/103/fd5ab1b5d832460395215f71fc024333/model/best_model
# 25 Creating embeddding file for /nrcan_p2/mlflow_data/98/c9d7feab3c3143d2b84c88de0119dca3/model/best_model
# 26 Creating embeddding file for /nrcan_p2/mlflow_data/102/f4bf6a9b7013428c89140d39a3bf2c59/model/best_model
# 27 Creating embeddding file for /nrcan_p2/mlflow_data/106/3258f9f79451477f87a639446295fba0/model/best_model
# 28 Creating embeddding file for /nrcan_p2/mlflow_data/104/dd946c63515e460a801e0631487cb1a5/model/best_model
# 29 Creating embeddding file for /nrcan_p2/mlflow_data/107/783b4970e8104255a8fed894b37ddc7a/model/best_model
# 30 Creating embeddding file for /nrcan_p2/mlflow_data/97/328ae3b4fa2a4b3ab94940d75422992f/model/best_model
# 31 Creating embeddding file for /nrcan_p2/mlflow_data/101/6de217a53bac450fa2e63fc2420a3d73/model/best_model
# 32 Creating embeddding file for /nrcan_p2/mlflow_data/105/9ea9830e8e4c4bb3be386be4605e5a68/model/best_model
# 33 Creating embeddding file for /nrcan_p2/mlflow_data/119/58541a9131dc40248198702d06e08d34/model/best_model
# 34 Creating embeddding file for /nrcan_p2/mlflow_data/120/ac505d9ae17e4a648fb15224dbb0ab10/model/best_model
# 35 Creating embeddding file for /nrcan_p2/mlflow_data/81/108721072d4840e78509f27ed2554422/model/best_model
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
models_df.embedding_path.tolist()[-2]
# Out:
# '/nrcan_p2/data/06_models/bert_nrcan_embeddings/bert.ab.90.geo500.786.txt'

# %%
# write embedding map to csv
models_df[["dataset", "pipeline", "tokenizer", "embedding_path", "dim"]].to_csv(f"{OUTPUT_FOLDER}/BERT_EMBEDDING_MAP.csv")
